# %% [markdown]
# # Intro video
#
# climate.gov climate change... Moana loa atmospheric CO2
# https://www.climate.gov/news-features/understanding-climate/climate-change-atmospheric-carbon-dioxide
#
# Mauna Loa data: https://gml.noaa.gov/ccgg/trends/data.html
#
# Mauna Loa Monthly average CO2: https://gml.noaa.gov/dv/data/index.php?parameter_name=Carbon%2BDioxide&type=Insitu&frequency=Monthly%2BAverages
#
#
# 1958
#
# theconversation.com/
# https://theconversation.com/the-three-minute-story-of-800-000-years-of-climate-change-with-a-sting-in-the-tail-73368
#
# (how much does temp lag co2?)
#
# Antarctica
# Global
#
# Jean-Robert Petit & Dominique Raynaud (forty years of ice-core records of CO2)
#
# https://en.wikipedia.org/wiki/European_Project_for_Ice_Coring_in_Antarctica
#
#
# Beyondepica.eu
#
# Luthi 2008 Nature paper - data in Pangaea https://doi.pangaea.de/10.1594/PANGAEA.710901
#
# https://www.ncei.noaa.gov/pub/data/paleo/icecore/antarctica/antarctica2015co2composite.txt
#
#
# grl52461.... use this one?
#
# temperature data (epicaDC***.xls) (edc3deuttemp2007.txt): https://www.ncei.noaa.gov/access/paleo-search/study/6080
#
# Correction on the dome c co2: https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2014GL061957
# Jouzel's data - ???

# %% [markdown]
# ## Assignment
#
# merge with moana loa data for temperature and CO2 from both + methane
#
# 1. recreate Fig 2 in Luthi (2008) in 41586_2008_BFnature06949_MOESM31_ESM.xls, use the temp as in edc3deuttemp2007.txt
# 2. Jouzel data (edc3deuttemp2007), Kelvin v data in epicaDC.deuttemp.EDC3-AICC.xls. Absolute temp in Kelvin v the temperature anomaly.
# 3. Methane or polar ice coverage
#     search: ncei.noaa.gov/access/paleo-search/
#     or: https://euanmearns.com/the-vostok-ice-core-temperature-co2-and-ch4/
#     there is a corrleation between temp nad ch4 (track down the methane daata)
#     polar ice: https://earth.gsfc.nasa.gov/cryo/data/arcticantarctic-sea-ice-time-series
#     check out antarctic data - 2023 how much outside mean??
#     total solar irradiance (TSI)
#
# 4. Ireland 0.88 per 1 deg global
#     - READ! https://www.sciencedirect.com/science/article/pii/S2212094723000610
#     - reproduce the analysis
#     - READ: https://www.sciencedirect.com/science/article/pii/S2212094722000469 (long-term trends in daily extreme air temperature indices i nireland from 2885 to 2018)
#     - met eireann long-term data sets
#     - stitch the 1885 data to modern data...
#
#
#
# Task 1 Data fusion (export to csv and json):
# - CO2 and temp at moana loa
# - Ice cores and historical temp
# - CH4 / ?
# - Irish temp and rainfall
#
# Task 2 Analysis
# - trends - relationship between variables co2/Temp co2/ch4, lead/lag? frequency analysis?
#
# Task 3 Data synthesis
# Temp
# Linear regression - what does data look like v published models
#
# Task 4
# Trads: Michael Mann/Chris Colose
# Accelerationists: Nick Coweren
# leon simons
#
#
# Mann - warming is linear, effects nonlinear (melting, storms, drought)
#
# Cowern - slope is changing - not linear increase in last couple decades....
#
# look at co2 and temp / what is recent increase? is this noise or real?
